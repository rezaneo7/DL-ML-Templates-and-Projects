# %%
# !pip install -U -q PyDrive 
  
from pydrive.auth import GoogleAuth 
from pydrive.drive import GoogleDrive 
from google.colab import auth 
from oauth2client.client import GoogleCredentials 
  
  
# Authenticate and create the PyDrive client. 
auth.authenticate_user() 
gauth = GoogleAuth() 
gauth.credentials = GoogleCredentials.get_application_default() 
drive = GoogleDrive(gauth)

# %%
from os import path
url = 'https://drive.google.com/file/d/1XJ2daZnHV5p0374MWjSMbY34nW3DExGY/view'
id = url.split("/")[-2] 
  
downloaded = drive.CreateFile({'id':id})  
downloaded.GetContentFile('school2.zip')

# %%
# !unzip school2.zip
# Out:
# Archive:  school2.zip
#   inflating: X_test.csv
#   inflating: X_train.csv
#   inflating: y_train.csv

# %%
import pandas as pd

df=  pd.read_csv("X_train.csv")
df
# Out:
#      StudentID school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         1714     GP   F   18       U     GT3       T     4     3     other
# 1         1254     GP   F   17       U     GT3       T     4     3    health
# 2         1639     GP   F   16       R     GT3       T     4     4    health
# 3         1118     GP   M   16       U     GT3       T     4     4  services
# 4         1499     GP   M   19       U     GT3       T     3     2  services
# ..         ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 673       1074     GP   M   15       U     GT3       T     4     4  services
# 674       1044     GP   M   15       R     GT3       T     4     4     other
# 675       1078     GP   M   17       U     LE3       T     4     4     other
# 676       1055     MS   M   17       R     GT3       T     1     1     other
# 677       1394     GP   F   17       U     GT3       T     3     2    health
#
# ...

# %%
df.describe(include='all').T
# Out:
#             count unique     top freq         mean         std     min  \
# StudentID   678.0    NaN     NaN  NaN  1516.181416  303.029891  1001.0
# school        678      2      GP  509          NaN         NaN     NaN
# sex           678      2       F  394          NaN         NaN     NaN
# age         678.0    NaN     NaN  NaN    16.719764    1.239881    15.0
# address       678      2       U  499          NaN         NaN     NaN
# famsize       678      2     GT3  479          NaN         NaN     NaN
# Pstatus       678      2       T  602          NaN         NaN     NaN
# Medu        678.0    NaN     NaN  NaN      2.60767    1.134682     0.0
# Fedu        678.0    NaN     NaN  NaN     2.371681     1.09675     0.0
# Mjob          678      5   other  254          NaN         NaN     NaN
# Fjob          678      5   other  371          NaN         NaN     NaN
# reason        678      4  course  269          NaN         NaN     NaN
# ...

# %%
test_df=  pd.read_csv("X_test.csv")
test_df
# Out:
#      StudentID school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         1000     GP   F   16       U     GT3       T     4     2  services
# 1         1008     GP   M   19       U     GT3       T     1     2     other
# 2         1013     GP   F   16       U     GT3       T     4     4  services
# 3         1014     GP   F   16       U     GT3       T     3     1  services
# 4         1017     GP   F   15       U     LE3       A     3     4     other
# ..         ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 361       2032     GP   F   15       R     LE3       T     3     1     other
# 362       2034     GP   M   17       U     GT3       T     3     3  services
# 363       2035     GP   F   16       U     GT3       T     2     3  services
# 364       2036     MS   F   16       U     GT3       T     3     1     other
# 365       2037     MS   M   18       U     GT3       T     4     4   teacher
#
# ...

# %%
y_df = pd.read_csv("y_train.csv")
y_df
# Out:
#      StudentID  G3
# 0         1714  14
# 1         1254  15
# 2         1639  11
# 3         1118  13
# 4         1499   0
# ..         ...  ..
# 673       1074  14
# 674       1044  11
# 675       1078  13
# 676       1055  10
# 677       1394  18
#
# [678 rows x 2 columns]

# %%
feature_imp_test = test_df.copy().drop(['StudentID', 'G1', 'G2'], axis=1)

# %%
feature_imp_test[['age', 'absences']] = scaler_num.transform(feature_imp_test[['age', 'absences']])

# %%
ohe_columns = []
for col in feature_imp_test.columns:
    if col not in ['age', 'absences']:
        ohe_columns.append(col)
        
feature_imp_test = pd.get_dummies(feature_imp_test, drop_first=True, columns=ohe_columns)

# %%
features_imp = df.copy().drop(['StudentID'], axis=1)
target_imp = y_df.copy()['G3']

# %%
print(features_imp.shape)
print(target_imp.shape)
# Out:
# (678, 32)
# (678,)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_predict
from xgboost import XGBRegressor
from sklearn.model_selection import RepeatedKFold
from sklearn.dummy import DummyRegressor

# %%
scaler_num = StandardScaler()
features_imp[['age', 'absences', 'G1', 'G2']] = scaler_num.fit_transform(features_imp[['age', 'absences', 'G1', 'G2']])

# %%
ohe_columns = []
for col in features_imp.columns:
    if col not in ['age', 'absences', 'G1', 'G2']:
        ohe_columns.append(col)
        
features_imp = pd.get_dummies(features_imp, drop_first=True, columns=ohe_columns)

# %%
linear_regressor = LinearRegression()
linear_regressor.fit(features_imp, target_imp)
# Out:
# LinearRegression()

# %%
feature_importances_lr_coef = pd.concat([pd.Series(features_imp.columns, name='features'), 
                                         pd.Series(linear_regressor.coef_, name='weights')],
                                        axis=1)

# %%
feature_importances_lr_coef
# Out:
#      features   weights
# 0         age  0.150130
# 1    absences  0.070395
# 2   school_MS -0.578750
# 3       sex_M  0.120692
# 4   address_U  0.400133
# ..        ...       ...
# 64     Walc_5  0.320221
# 65   health_2 -0.294544
# 66   health_3 -1.418379
# 67   health_4 -0.922140
# 68   health_5 -0.964847
#
# [69 rows x 2 columns]

# %%
feature_importances_lr_coef['weights'] = abs(feature_importances_lr_coef['weights'])

# %%
feature_importances_lr_coef = feature_importances_lr_coef.sort_values(by='weights', ascending=False).reset_index(drop=True)

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=feature_importances_lr_coef[:20], x='features', y='weights')
plt.xticks(rotation=45)
plt.show()

# %%
parameters = {'max_depth' : [8, 10, 12, 20],
              'n_estimators' : [200, 250, 300],
              'max_features' : [5, 25, 50],
              'min_samples_split' : [2, 4, 6]}
grid_search = GridSearchCV(estimator = RandomForestRegressor(random_state=42),
                           param_grid = parameters,
                           scoring = 'neg_mean_squared_error',
                           cv = 5)
grid_search.fit(features_imp, target_imp)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#              param_grid={'max_depth': [8, 10, 12, 20],
#                          'max_features': [5, 25, 50],
#                          'min_samples_split': [2, 4, 6],
#                          'n_estimators': [200, 250, 300]},
#              scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'max_depth': 8,
#  'max_features': 50,
#  'min_samples_split': 6,
#  'n_estimators': 250}

# %%
regressor_rf = RandomForestRegressor(max_depth=8, n_estimators=250, max_features=50, min_samples_split=6, random_state=42)
regressor_rf.fit(features_imp, target_imp)
# Out:
# RandomForestRegressor(max_depth=8, max_features=50, min_samples_split=6,
#                       n_estimators=250, random_state=42)

# %%
feature_importances_rf = pd.concat([pd.Series(features_imp.columns, name='features'), 
                                    pd.Series(regressor_rf.feature_importances_, name='importance')],
                                    axis=1).sort_values(by='importance', ascending=False).reset_index(drop=True)

# %%
feature_importances_rf
# Out:
#         features  importance
# 0             G2    0.681578
# 1             G1    0.164869
# 2       absences    0.067587
# 3            age    0.005640
# 4     failures_2    0.004314
# ..           ...         ...
# 66  traveltime_3    0.000393
# 67   Mjob_health    0.000384
# 68   Fjob_health    0.000346
# 69  Fjob_teacher    0.000239
# 70        Dalc_4    0.000157
#
# [71 rows x 2 columns]

# %%
plt.figure(figsize=(15,9))
sns.barplot(data=feature_importances_rf[:20], x='features', y='importance')
plt.xticks(rotation=45)
plt.show()

# %%
feature_importances_rf['features'][0:5].values
# Out:
# array(['G2', 'G1', 'absences', 'age', 'failures_2'], dtype=object)

# %%
feature_train = features_imp[feature_importances_rf['features'][0:5].values]

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

val_error_rate = []
neighbors_range = range(1,500,5)

for i in neighbors_range:
    
    knn = KNeighborsClassifier(n_neighbors=i)
    
    val_error = 1 - cross_val_score(knn,feature_train, target_imp,cv=5).mean()
    val_error_rate.append(val_error)

# Plot settings
plt.figure(figsize=(15,7))
plt.plot(neighbors_range, val_error_rate, color='orange', linestyle='dashed', marker='o',
         markerfacecolor='black', markersize=5, label='Validation Error')
plt.xticks(np.arange(neighbors_range.start, neighbors_range.stop, neighbors_range.step), rotation=60)
plt.grid()
plt.legend()
plt.title('Validation Error vs. K Value')
plt.xlabel('K')
plt.ylabel('Validation Error')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   UserWarning,
# ...

# %%
train_test_df = pd.concat([df, test_df], ignore_index=True)

# %%
len(df)
# Out:
# 678

# %%
data = pd.get_dummies(train_test_df)

# %%
labels = y_df["G3"]
features = data.copy().drop(['StudentID', "G1", "G2", "failures", "absences"], axis=1)

feature_list = list(features.columns)
features = np.array(features)
labels = np.array(labels)

# %%
from sklearn.model_selection import train_test_split
#features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size = 0.3, random_state = 42)
features_train = features[0:678]
features_test = features[678:]
labels_train = labels

diz_performance_train = {}
diz_performance_test = {}

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
features_train = scaler.fit_transform(features_train)
features_test = scaler.transform(features_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
def get_metrics(features, labels, clf):
    pred = clf.predict(features)
    R2 = r2_score(labels, pred)
    MSE = mean_squared_error(labels, pred)
    MAE = mean_absolute_error(labels, pred)
    r2_adj = 1 - (1-R2)*(len(labels)-1)/(len(labels)-features.shape[1]-1)
    if r2_adj < 0:
        r2_adj = 0
    return (R2, r2_adj, MSE, MAE)

def metrics_print(metrics):
    
    print("R square = ", round(metrics[0], 3))
    print("R Square adj = ", round(metrics[1],3))
    print("MSE = ", round(metrics[2],3))
    print("MAE = ", round(metrics[3],3))

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
svr = SVR()
param = [{"kernel": ["linear"],"C": [0.001,0.01, 0.1, 1,10,100, 1000], "epsilon": [0.0, 0.1, 0.01, 0.02]},
        {"kernel": ["rbf"], "C":[0.001, 0.01, 0.1, 1, 10, 100, 1000], "gamma": [0.001, 0.01, 0.1, 1, 10, 100, 1000], "epsilon": [0.0, 0.1, 0.01, 0.001]}]
svr_best = GridSearchCV(svr, param, verbose = 1, n_jobs = -1, return_train_score = True, scoring= 'neg_mean_absolute_error')
svr_best.fit(features_train, labels_train)
# Out:
# Fitting 5 folds for each of 224 candidates, totalling 1120 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid=[{'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                           'epsilon': [0.0, 0.1, 0.01, 0.02],
#                           'kernel': ['linear']},
#                          {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                           'epsilon': [0.0, 0.1, 0.01, 0.001],
#                           'gamma': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                           'kernel': ['rbf']}],
#              return_train_score=True, scoring='neg_mean_absolute_error',
#              verbose=1)

# %%
svr_best.best_params_
# Out:
# {'C': 1, 'epsilon': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
print("Training set")
diz_performance_train["SVR"] = get_metrics(features_train, labels_train, svr_best)
metrics_print(diz_performance_train["SVR"])

print("\nTest set")
#diz_performance_test["SVR"] = get_metrics(features_test, labels_test, svr_best)
#metrics_print(diz_performance_test["SVR"])
# Out:
# Training set
# R square =  0.269
# R Square adj =  0.206
# MSE =  10.723
# MAE =  2.086
#
# Test set

# %%
y_pred = svr_best.predict(features_test)

# %%
def g3_calc(val1, val2):

  return np.average([val1, val2], weights=[1, 5])
test_df['G3'] = test_df.apply(lambda x: g3_calc(x['G1'], x['G2']), axis = 1)

# %%
data = {"StudentID" : test_df["StudentID"].values, "Score": test_df['G3']}
df_y_test = pd.DataFrame(data)

# %%
df_y_test.to_csv("out.csv", index = False)

# %%
test_df
# Out:
#      StudentID school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0         1000     GP   F   16       U     GT3       T     4     2  services
# 1         1008     GP   M   19       U     GT3       T     1     2     other
# 2         1013     GP   F   16       U     GT3       T     4     4  services
# 3         1014     GP   F   16       U     GT3       T     3     1  services
# 4         1017     GP   F   15       U     LE3       A     3     4     other
# ..         ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 361       2032     GP   F   15       R     LE3       T     3     1     other
# 362       2034     GP   M   17       U     GT3       T     3     3  services
# 363       2035     GP   F   16       U     GT3       T     2     3  services
# 364       2036     MS   F   16       U     GT3       T     3     1     other
# 365       2037     MS   M   18       U     GT3       T     4     4   teacher
#
# ...
